# %% [raw]
# # Práctica 1.

# %%
print("Hola desde Jupyter.")
# Out:
# Hola desde Jupyter.

# %%
text = "Las variables de otras líneas se pueden usar"
text2 = "siempre y cuando se ejecuten de manera secuencial."

# %%
# Por ejemplo. Si no ejecutas la línea 2, entonces la línea 3 no podrá mostrar los valores de text.
print("Text 1: " + text)
print("Text 2: " + text2)
# Out:
# Text 1: Las variables de otras líneas se pueden usar
# Text 2: siempre y cuando se ejecuten de manera secuencial.

# %%
# Suma
a = 10
b = 21
r = a + b

# %%
print("Suma = " + str(r))
# Out:
# Suma = 31
